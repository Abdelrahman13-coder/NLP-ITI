# %% [markdown]
# <h1 align=center>Text Classification</h1>
#
# This is our `hello world` example

# %%
#!pip install eli5 --user

# %%
import eli5

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# a helper functions and imports
from IPython.display import display
def highlight_col(x, df):
    #set by condition
    mask =  df['label'] == 'pos'
    mask2 = df['label'] == 'neg'
    x = pd.DataFrame('', index=df.index, columns=df.columns)
    x.loc[mask] = 'background-color: #e6ffe6'
    x.loc[mask2] = 'background-color: #ffe6e6'
    return x

# %% [markdown]
# ## Load the data

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

train_pos = pd.read_csv("train_Arabic_tweets_positive_20190413.tsv",
                        sep='\t', header=None)
train_neg = pd.read_csv("train_Arabic_tweets_negative_20190413.tsv",
                        sep='\t', header=None)
train_data = pd.concat([train_pos, train_neg], ignore_index=True)
train_data.columns = ['label', 'tweet']
del train_pos, train_neg

pd.set_option('display.max_colwidth', 100000)
df_tmp = train_data.sample(5)
df_tmp.style.apply(lambda x: highlight_col(x, df_tmp), axis=None)
# Out:
# <style type="text/css">
# #T_4f4aa_row0_col0, #T_4f4aa_row0_col1, #T_4f4aa_row1_col0, #T_4f4aa_row1_col1, #T_4f4aa_row3_col0, #T_4f4aa_row3_col1 {
#   background-color: #ffe6e6;
# }
# #T_4f4aa_row2_col0, #T_4f4aa_row2_col1, #T_4f4aa_row4_col0, #T_4f4aa_row4_col1 {
#   background-color: #e6ffe6;
# }
# </style>
# <table id="T_4f4aa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f4aa_level0_col0" class="col_heading level0 col0" >label</th>
#       <th id="T_4f4aa_level0_col1" class="col_heading level0 col1" >tweet</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f4aa_level0_row0" class="row_heading level0 row0" >28671</th>
#       <td id="T_4f4aa_row0_col0" class="data row0 col0" >neg</td>
#       <td id="T_4f4aa_row0_col1" class="data row0 col1" >اللهم حبك وحب من يحبك وكل حب يقربنا إلى حبك ❤ يسعد صباحكوو ✋</td>
#     </tr>
#     <tr>
#       <th id="T_4f4aa_level0_row1" class="row_heading level0 row1" >36997</th>
#       <td id="T_4f4aa_row1_col0" class="data row1 col0" >neg</td>
#       <td id="T_4f4aa_row1_col1" class="data row1 col1" >ان شاء الله تحسون عاد 😂:) 💔</td>
#     </tr>
#     <tr>
#       <th id="T_4f4aa_level0_row2" class="row_heading level0 row2" >20451</th>
#       <td id="T_4f4aa_row2_col0" class="data row2 col0" >pos</td>
#       <td id="T_4f4aa_row2_col1" class="data row2 col1" >أوجاعك التي لم يلتفت لها أحد ، هي تحت عناية الله سبحانه ، ثق دائما بالله ولا تفقد الأمل انهو على كل شي قدير صبا…</td>
#     </tr>
#     <tr>
#       <th id="T_4f4aa_level0_row3" class="row_heading level0 row3" >37204</th>
#       <td id="T_4f4aa_row3_col0" class="data row3 col0" >neg</td>
#       <td id="T_4f4aa_row3_col1" class="data row3 col1" >هاذا الفساد بأم عينه 😭 الله يكفينا الشر</td>
#     </tr>
#     <tr>
#       <th id="T_4f4aa_level0_row4" class="row_heading level0 row4" >17042</th>
#       <td id="T_4f4aa_row4_col0" class="data row4 col0" >pos</td>
#       <td id="T_4f4aa_row4_col1" class="data row4 col1" >اصحى على الدنيا مطر 😍</td>
#     </tr>
#   </tbody>
# </table>

# %%
test_pos = pd.read_csv("test_Arabic_tweets_positive_20190413.tsv",
                        sep='\t', header=None)
test_neg = pd.read_csv("test_Arabic_tweets_negative_20190413.tsv",
                        sep='\t', header=None)
test_data = pd.concat([test_pos, test_neg], ignore_index=True)
test_data.columns = ['label', 'tweet']
del test_pos, test_neg

df_tmp = test_data.sample(5)
df_tmp.style.apply(lambda x: highlight_col(x, df_tmp), axis=None)
# Out:
# <style type="text/css">
# #T_f8db0_row0_col0, #T_f8db0_row0_col1, #T_f8db0_row2_col0, #T_f8db0_row2_col1 {
#   background-color: #ffe6e6;
# }
# #T_f8db0_row1_col0, #T_f8db0_row1_col1, #T_f8db0_row3_col0, #T_f8db0_row3_col1, #T_f8db0_row4_col0, #T_f8db0_row4_col1 {
#   background-color: #e6ffe6;
# }
# </style>
# <table id="T_f8db0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8db0_level0_col0" class="col_heading level0 col0" >label</th>
#       <th id="T_f8db0_level0_col1" class="col_heading level0 col1" >tweet</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8db0_level0_row0" class="row_heading level0 row0" >7096</th>
#       <td id="T_f8db0_row0_col0" class="data row0 col0" >neg</td>
#       <td id="T_f8db0_row0_col1" class="data row0 col1" >تلاتين سنة بترقص .. الليلة رقصتنا أنا ببكي 😭 دي حلاوة شديدة باخ</td>
#     </tr>
#     <tr>
#       <th id="T_f8db0_level0_row1" class="row_heading level0 row1" >1213</th>
#       <td id="T_f8db0_row1_col0" class="data row1 col0" >pos</td>
#       <td id="T_f8db0_row1_col1" class="data row1 col1" >هذا كلام إعلامي يظهر في قناة (حكوميه) ! الدعوه سايبه يا حبيبي 🙂 و قبلها اساء لحمدالله لا إلتزام بالحياد و لا احترام…</td>
#     </tr>
#     <tr>
#       <th id="T_f8db0_level0_row2" class="row_heading level0 row2" >11032</th>
#       <td id="T_f8db0_row2_col0" class="data row2 col0" >neg</td>
#       <td id="T_f8db0_row2_col1" class="data row2 col1" >هه 😂 💔 👊</td>
#     </tr>
#     <tr>
#       <th id="T_f8db0_level0_row3" class="row_heading level0 row3" >914</th>
#       <td id="T_f8db0_row3_col0" class="data row3 col0" >pos</td>
#       <td id="T_f8db0_row3_col1" class="data row3 col1" >💎درر الجمعة💎 ۞ ﷽ ۞ . *(فارتدا علىٰ آثارهما قصصا)* 🌧.. تعلمنا سورة الكهف أن النجاح لا…</td>
#     </tr>
#     <tr>
#       <th id="T_f8db0_level0_row4" class="row_heading level0 row4" >1750</th>
#       <td id="T_f8db0_row4_col0" class="data row4 col0" >pos</td>
#       <td id="T_f8db0_row4_col1" class="data row4 col1" >#ساعه_استجابه اللهم لا تحرمنا سعة رحمتك ، وسبوغ نعمتك ، وشمول عافيتك ، وجزيل عطائك ، أنت الحليم فلا تعجل ، وأنت ال…</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Baseline model (using pipeline)

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.pipeline import make_pipeline

vec = CountVectorizer()
clf = LogisticRegression()
pipe = make_pipeline(vec, clf)
pipe.fit(train_data.tweet, train_data.label);

# %% [markdown]
# Let's test this basic model

# %%
from sklearn import metrics

def print_report(pipe, x_test, y_test):
    y_pred = pipe.predict(x_test)
    report = metrics.classification_report(y_test, y_pred)
    print(report)
    print("accuracy: {:0.3f}".format(metrics.accuracy_score(y_test, y_pred)))

print_report(pipe, test_data.tweet, test_data.label)
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.77      0.82      0.80      5768
#          pos       0.81      0.76      0.78      5752
#
#     accuracy                           0.79     11520
#    macro avg       0.79      0.79      0.79     11520
# weighted avg       0.79      0.79      0.79     11520
#
# accuracy: 0.792

# %% [markdown]
# ## let's take a look inside the model

# %%
eli5.show_weights(clf, vec=vec, top=20)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=pos
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.779
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         الإخونج
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.88%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.414
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         وصباحك
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.93%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.216
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         هالسنه
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.60%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.093
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         ابريل
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.61%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.092
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         السحب
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.64%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.086
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         الزرقاء
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.70%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.075
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         برونو
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.96%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.029
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         اللوك
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.75%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.887
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         الطيب
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.79%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.880
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         حكمة
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.89%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.862
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         مبروك
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.17%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.813
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         ريهام
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 85.17%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 36163 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 85.31%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 34674 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 85.31%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.788
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         مناحل_ابو_سلطان
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 85.14%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.819
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         فاتني
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 85.12%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.822
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         خرووج
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.988
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         يستر
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 83.36%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -2.138
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         زعيم_تويتر_فولورز_اهلاوي
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 82.92%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -2.218
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         مسلسل_ودك_يتكرر_برمضان
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 82.73%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -2.253
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         أجباري_وليس_أختياري
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 81.25%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -2.534
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         امطار_الشرقيه
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>

# %% [markdown]
# ## Try our model on some tweets

# %%
for _, row in test_data.sample(5).iterrows():
    print(f"true label: {row['label']}")
    display(eli5.show_prediction(clf, row['tweet'], vec=vec,))
    print("--"*50)
# Out:
# true label: neg
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=neg
#
# </b>
#
#
#     (probability <b>0.814</b>, score <b>-1.478</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.144
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 91.56%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.334
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">✔️ </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.391">الحلقة</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 80.92%); opacity: 0.87" title="0.136">الثلاثون</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.20%); opacity: 0.80" title="-0.005">من</span><span style="opacity: 0.80"> #</span><span style="background-color: hsl(120, 100.00%, 66.05%); opacity: 0.96" title="0.309">السيرة_النبوية_في_تغريدات</span><span style="opacity: 0.80"> 💥 </span><span style="background-color: hsl(120, 100.00%, 63.55%); opacity: 0.98" title="0.342">أحداث</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 84.40%); opacity: 0.85" title="-0.102">جرت</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 83.88%); opacity: 0.85" title="-0.107">في</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 76.81%); opacity: 0.89" title="0.179">طريق</span><span style="opacity: 0.80"> هجرته ﷺ…</span>
#     </p>
# ----------------------------------------------------------------------------------------------------
# true label: neg
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=pos
#
# </b>
#
#
#     (probability <b>0.554</b>, score <b>0.216</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.549
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 85.90%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.334
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 69.61%); opacity: 0.94" title="0.374">العائلة</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 91.12%); opacity: 0.82" title="-0.065">اللي</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.554">تستحق</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 62.11%); opacity: 0.99" title="-0.513">العيش</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 80.48%); opacity: 0.87" title="0.199">بسعادة</span><span style="opacity: 0.80">😭💔💔</span>
#     </p>
# ----------------------------------------------------------------------------------------------------
# true label: pos
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=pos
#
# </b>
#
#
#     (probability <b>0.780</b>, score <b>1.266</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.599
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 93.32%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.334
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 61.89%); opacity: 0.99" title="0.698">صباح</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 85.48%); opacity: 0.85" title="0.176">الخير</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.57%); opacity: 0.81" title="-0.022">يا</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.748">قطر</span><span style="opacity: 0.80"> 😂 ..</span>
#     </p>
# ----------------------------------------------------------------------------------------------------
# true label: pos
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=pos
#
# </b>
#
#
#     (probability <b>0.759</b>, score <b>1.146</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.479
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 92.95%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.334
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(0, 100.00%, 91.65%); opacity: 0.82" title="-0.172">تجمع</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.82%); opacity: 0.80" title="-0.025">المهنيين</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="1.614">حبنا</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.00%); opacity: 0.80" title="-0.022">يا</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.90%); opacity: 0.81" title="0.085">زول</span><span style="opacity: 0.80"> ❤</span>
#     </p>
# ----------------------------------------------------------------------------------------------------
# true label: pos
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=pos
#
# </b>
#
#
#     (probability <b>0.980</b>, score <b>3.887</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.220
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 96.61%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.334
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">#</span><span style="background-color: hsl(0, 100.00%, 74.61%); opacity: 0.90" title="-0.458">النصرالاتحاد</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 70.95%); opacity: 0.93" title="0.555">العالمي</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.877">ابو</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 80.40%); opacity: 0.87" title="-0.317">هديل</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 85.73%); opacity: 0.85" title="0.201">مع</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 70.95%); opacity: 0.93" title="0.555">العالمي</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 68.51%); opacity: 0.94" title="0.623">النصر</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 66.46%); opacity: 0.96" title="0.682">وكلنا</span><span style="opacity: 0.80"> للنصرالجزيرة </span><span style="background-color: hsl(120, 100.00%, 70.95%); opacity: 0.93" title="0.555">العالمي</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 66.68%); opacity: 0.95" title="0.676">حاضرين</span><span style="opacity: 0.80"> #</span><span style="background-color: hsl(120, 100.00%, 82.51%); opacity: 0.86" title="0.269">زلازل_الملعب_نصرنا_بيلعب</span><span style="opacity: 0.80"> 💛💙💛💙💛💙💛…</span>
#     </p>
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Try Tfidf with some processing

# %%
vec = TfidfVectorizer(analyzer='char_wb', ngram_range=(3, 5), min_df=.01, max_df=.3)
clf = LinearSVC()
pipe_tfidf = make_pipeline(vec, clf)
pipe_tfidf.fit(train_data.tweet, train_data.label)
# Out:
# Pipeline(steps=[('tfidfvectorizer',
#                  TfidfVectorizer(analyzer='char_wb', max_df=0.3, min_df=0.01,
#                                  ngram_range=(3, 5))),
#                 ('linearsvc', LinearSVC())])

# %%
print_report(pipe_tfidf, test_data.tweet, test_data.label)
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.85      0.82      0.84      5768
#          pos       0.83      0.86      0.84      5752
#
#     accuracy                           0.84     11520
#    macro avg       0.84      0.84      0.84     11520
# weighted avg       0.84      0.84      0.84     11520
#
# accuracy: 0.838

# %%
eli5.show_weights(clf, vec=vec, top=20)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=pos
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.43%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.905
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         <span style="background-color: hsl(120, 80%, 70%); margin: 0 0.1em 0 0" title="A space symbol">&emsp;</span>😂<span style="background-color: hsl(120, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.35%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.245
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         <span style="background-color: hsl(120, 80%, 70%); margin: 0 0.1em 0 0" title="A space symbol">&emsp;</span>💙<span style="background-color: hsl(120, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.38%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.222
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         <span style="background-color: hsl(120, 80%, 70%); margin: 0 0.1em 0 0" title="A space symbol">&emsp;</span>💛<span style="background-color: hsl(120, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 90.31%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.580
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         <span style="background-color: hsl(120, 80%, 70%); margin: 0 0.1em 0 0" title="A space symbol">&emsp;</span>🌹<span style="background-color: hsl(120, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 91.40%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.866
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         <span style="background-color: hsl(120, 80%, 70%); margin: 0 0.1em 0 0" title="A space symbol">&emsp;</span>🤣<span style="background-color: hsl(120, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 91.41%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.858
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         <span style="background-color: hsl(120, 80%, 70%); margin: 0 0.1em 0 0" title="A space symbol">&emsp;</span>❤<span style="background-color: hsl(120, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 91.61%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.727
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         <span style="background-color: hsl(120, 80%, 70%); margin: 0 0.1em 0 0" title="A space symbol">&emsp;</span>😍<span style="background-color: hsl(120, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 93.03%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.864
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         تويت<span style="background-color: hsl(120, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 93.56%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.555
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         <span style="background-color: hsl(120, 80%, 70%); margin: 0 0.1em 0 0" title="A space symbol">&emsp;</span>💪<span style="background-color: hsl(120, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 93.56%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 772 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 93.45%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 741 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 93.45%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -2.618
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         <span style="background-color: hsl(0, 80%, 70%); margin: 0 0.1em 0 0" title="A space symbol">&emsp;</span>😏<span style="background-color: hsl(0, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 92.50%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.175
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         <span style="background-color: hsl(0, 80%, 70%); margin: 0 0.1em 0 0" title="A space symbol">&emsp;</span>:(<span style="background-color: hsl(0, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 92.50%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.175
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         :(<span style="background-color: hsl(0, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 92.28%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.312
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         لال<span style="background-color:

# %%
for _, row in test_data.sample(5).iterrows():
    print(f"true label: {row['label']}")
    display(eli5.show_prediction(clf, row['tweet'], vec=vec,))
    print("--"*50)
# Out:
# true label: neg
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=neg
#
# </b>
#
#
#     (score <b>-0.571</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.656
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 95.24%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.084
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 89.51%); opacity: 0.83" title="0.018">ا</span><span style="background-color: hsl(120, 100.00%, 99.46%); opacity: 0.80" title="0.000">لي</span><span style="background-color: hsl(120, 100.00%, 76.21%); opacity: 0.90" title="0.059"> </span><span style="background-color: hsl(120, 100.00%, 73.95%); opacity: 0.91" title="0.067">يت</span><span style="opacity: 0.80">غاز</span><span style="background-color: hsl(0, 100.00%, 84.41%); opacity: 0.85" title="-0.032">ل</span><span style="background-color: hsl(0, 100.00%, 81.65%); opacity: 0.87" title="-0.041">ون</span><span style="background-color: hsl(0, 100.00%, 89.26%); opacity: 0.83" title="-0.019"> </span><span style="opacity: 0.80">ا</span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.124">طلع</span><span style="opacity: 0.80">وو</span><span style="background-color: hsl(120, 100.00%, 87.45%); opacity: 0.84" title="0.024"> بر</span><span style="opacity: 0.80">ا</span><span style="background-color: hsl(120, 100.00%, 80.66%); opacity: 0.87" title="0.044">اه </span><span style="opacity: 0.80">😷</span>
#     </p>
# ----------------------------------------------------------------------------------------------------
# true label: pos
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=pos
#
# </b>
#
#
#     (score <b>0.561</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.477
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 94.05%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.084
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 68.76%); opacity: 0.94" title="0.081">ص</span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.115">ب</span><span style="background-color: hsl(120, 100.00%, 69.86%); opacity: 0.93" title="0.077">ا</span><span style="background-color: hsl(0, 100.00%, 91.26%); opacity: 0.82" title="-0.013">ح</span><span style="background-color: hsl(120, 100.00%, 89.95%); opacity: 0.83" title="0.016"> </span><span style="background-color: hsl(120, 100.00%, 95.05%); opacity: 0.81" title="0.006">ا</span><span style="background-color: hsl(120, 100.00%, 78.27%); opacity: 0.88" title="0.048">ل</span><span style="background-color: hsl(120, 100.00%, 76.07%); opacity: 0.90" title="0.055">خ</span><span style="background-color: hsl(120, 100.00%, 80.08%); opacity: 0.87" title="0.043">ي</span><span style="background-color: hsl(120, 100.00%, 70.15%); opacity: 0.93" title="0.076">ر</span><span style="background-color: hsl(0, 100.00%, 85.53%); opacity: 0.85" title="-0.027"> </span><span style="opacity: 0.80">☘️</span>
#     </p>
# ----------------------------------------------------------------------------------------------------
# true label: neg
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=neg
#
# </b>
#
#
#     (score <b>-2.103</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.188
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 97.95%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.084
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 61.38%); opacity: 0.99" title="1.017">💔</span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="1.069"> </span><span style="background-color: hsl(120, 100.00%, 95.64%); opacity: 0.81" title="0.045">ا</span><span style="background-color: hsl(0, 100.00%, 96.85%); opacity: 0.81" title="-0.028">ل</span><span style="background-color: hsl(0, 100.00%, 99.56%); opacity: 0.80" title="-0.002">ج</span><span style="background-color: hsl(0, 100.00%, 96.75%); opacity: 0.81" title="-0.030">م</span><span style="background-color: hsl(120, 100.00%, 96.03%); opacity: 0.81" title="0.039">ي</span><span style="background-color: hsl(120, 100.00%, 94.99%); opacity: 0.81" title="0.055">ع</span><span style="background-color: hsl(120, 100.00%, 92.76%); opacity: 0.82" title="0.093"> </span><span style="background-color: hsl(120, 100.00%, 95.22%); opacity: 0.81" title="0.051">ل</span><span style="background-color: hsl(120, 100.00%, 93.40%); opacity: 0.82" title="0.082">ي</span><span style="background-color: hsl(120, 100.00%, 97.48%); opacity: 0.80" title="0.021">س</span><span style="background-color: hsl(120, 100.00%, 93.64%); opacity: 0.81" title="0.077"> </span><span style="background-color: hsl(120, 100.00%, 95.50%); opacity: 0.81" title="0.047">ح</span><span style="background-color: hsl(120, 100.00%, 98.50%); opacity: 0.80" title="0.010">ق</span><span style="background-color: hsl(0, 100.00%, 91.37%); opacity: 0.82" title="-0.119">ي</span><span style="background-color: hsl(0, 100.00%, 90.75%); opacity: 0.82" title="-0.132">ق</span><span style="background-color: hsl(0, 100.00%, 92.67%); opacity: 0.82" title="-0.095">ي</span>
#     </p>
# ----------------------------------------------------------------------------------------------------
# true label: pos
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=pos
#
# </b>
#
#
#     (score <b>1.201</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.116
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.72%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.084
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 81.03%); opacity: 0.87" title="0.060">ا</span><span style="background-color: hsl(120, 100.00%, 93.35%); opacity: 0.82" title="0.013">ل</span><span style="background-color: hsl(120, 100.00%, 84.76%); opacity: 0.85" title="0.044">ل</span><span style="background-color: hsl(120, 100.00%, 93.34%); opacity: 0.82" title="0.013">ه</span><span style="background-color: hsl(0, 100.00%, 94.70%); opacity: 0.81" title="-0.010">م</span><span style="background-color: hsl(0, 100.00%, 88.86%); opacity: 0.83" title="-0.028"> </span><span style="background-color: hsl(120, 100.00%, 92.23%); opacity: 0.82" title="0.017">إن</span><span style="background-color: hsl(120, 100.00%, 88.09%); opacity: 0.84" title="0.031"> </span><span style="background-color: hsl(120, 100.00%, 94.55%); opacity: 0.81" title="0.010">في</span><span style="background-color: hsl(0, 100.00%, 96.53%); opacity: 0.81" title="-0.005"> </span><span style="background-color: hsl(0, 100.00%, 95.00%); opacity: 0.81" title="-0.009">ص</span><span style="background-color: hsl(120, 100.00%, 95.37%); opacity: 0.81" title="0.008">د</span><span style="background-color: hsl(120, 100.00%, 86.16%); opacity: 0.84" title="0.038">ري</span><span style="background-color: hsl(0, 100.00%, 93.01%); opacity: 0.82" title="-0.014"> </span><span style="background-color: hsl(120, 100.00%, 99.55%); opacity: 0.80" title="0.000">ك</span><span style="background-color: hsl(120, 100.00%, 95.56%); opacity: 0.81" title="0.008">ل</span><span style="background-color: hsl(120, 100.00%, 99.51%); opacity: 0.80" title="0.000">ا</span><span style="background-color: hsl(0, 100.00%, 95.34%); opacity: 0.81" title="-0.008">م</span><span style="background-color: hsl(0, 100.00%, 95.77%); opacity: 0.81" title="-0.007">ا</span><span style="background-color: hsl(0, 100.00%, 86.91%); opacity: 0.84" title="-0.035"> </span><span style="background-color: hsl(0, 100.00%, 95.20%); opacity: 0.81" title="-0.008">لا</span><span style="background-color: hsl(120, 100.00%, 86.02%); opacity: 0.84" title="0.039"> </span><span style="background-color: hsl(120, 100.00%, 90.22%); opacity: 0.83" title="0.023">أس</span><span style="opacity: 0.80">تط</span><span style="background-color: hsl(0, 100.00%, 93.01%); opacity: 0.82" title="-0.014">يع</span><span style="background-color: hsl(120, 100.00%, 97.67%); opacity: 0.80" title="0.003"> </span><span style="background-color: hsl(120, 100.00%, 92.02%); opacity: 0.82" title="0.017">تر</span><span style="opacity: 0.80">تي</span><span style="background-color: hsl(120, 100.00%, 96.28%); opacity: 0.81" title="0.006">به</span><span style="background-color: hsl(120, 100.00%, 92.93%); opacity: 0.82" title="0.015"> </span><span style="background-color: hsl(120, 100.00%, 94.55%); opacity: 0.81" title="0.010">في</span><span style="background-color: hsl(120, 100.00%, 88.36%); opacity: 0.83" title="0.030"> </span><span style="background-color: hsl(120, 100.00%, 95.06%); opacity: 0.81" title="0.009">الد</span><span style="opacity: 0.80">ع</span><span style="background-color: hsl(0, 100.00%, 96.15%); opacity: 0.81" title="-0.006">اء</span><span style="background-color: hsl(120, 100.00%, 95.32%); opacity: 0.81" title="0.008"> </span><span style="background-color: hsl(120, 100.00%, 99.44%); opacity: 0.80" title="0.000">..</span><span style="background-color: hsl(0, 100.00%, 96.69%); opacity: 0.81" title="-0.005"> </span><span style="background-color: hsl(120, 100.00%, 96.01%); opacity: 0.81" title="0.007">ف</span><span style="background-color: hsl(0, 100.00%, 98.46%); opacity: 0.80" title="-0.002">ي</span><span style="background-color: hsl(120, 100.00%, 89.92%); opacity: 0.83" title="0.024">ا</span><span style="background-color: hsl(120, 100.00%, 92.68%); opacity: 0.82" title="0.015">ر</span><span style="background-color: hsl(120, 100.00%, 87.76%); opacity: 0.84" title="0.032">ب</span><span style="background-color: hsl(0, 100.00%, 93.85%); opacity: 0.81" title="-0.0 ...
# ----------------------------------------------------------------------------------------------------
# true label: pos
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=pos
#
# </b>
#
#
#     (score <b>0.505</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.420
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 93.50%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.084
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(0, 100.00%, 84.08%); opacity: 0.85" title="-0.017">من</span><span style="background-color: hsl(120, 100.00%, 96.86%); opacity: 0.81" title="0.002"> </span><span style="background-color: hsl(120, 100.00%, 93.69%); opacity: 0.81" title="0.005">الن</span><span style="opacity: 0.80">ع</span><span style="background-color: hsl(120, 100.00%, 93.61%); opacity: 0.81" title="0.005">يم</span><span style="background-color: hsl(120, 100.00%, 90.87%); opacity: 0.82" title="0.008"> </span><span style="background-color: hsl(120, 100.00%, 88.87%); opacity: 0.83" title="0.010">أن</span><span style="background-color: hsl(120, 100.00%, 76.54%); opacity: 0.89" title="0.030"> </span><span style="background-color: hsl(120, 100.00%, 86.10%); opacity: 0.84" title="0.014">ت</span><span style="background-color: hsl(120, 100.00%, 87.57%); opacity: 0.84" title="0.012">ج</span><span style="background-color: hsl(0, 100.00%, 96.36%); opacity: 0.81" title="-0.002">د</span><span style="background-color: hsl(0, 100.00%, 80.79%); opacity: 0.87" title="-0.022"> </span><span style="background-color: hsl(0, 100.00%, 90.60%); opacity: 0.83" title="-0.008">من</span><span style="background-color: hsl(120, 100.00%, 96.25%); opacity: 0.81" title="0.002"> </span><span style="background-color: hsl(0, 100.00%, 88.14%); opacity: 0.84" title="-0.011">لا</span><span style="background-color: hsl(120, 100.00%, 81.83%); opacity: 0.86" title="0.021"> </span><span style="opacity: 0.80">يضط</span><span style="background-color: hsl(120, 100.00%, 79.75%); opacity: 0.88" title="0.024">رك</span><span style="background-color: hsl(120, 100.00%, 94.99%); opacity: 0.81" title="0.003"> </span><span style="background-color: hsl(0, 100.00%, 97.31%); opacity: 0.80" title="-0.001">إ</span><span style="background-color: hsl(120, 100.00%, 94.65%); opacity: 0.81" title="0.004">ل</span><span style="background-color: hsl(120, 100.00%, 67.77%); opacity: 0.95" title="0.046">ى</span><span style="background-color: hsl(120, 100.00%, 75.43%); opacity: 0.90" title="0.032"> </span><span style="background-color: hsl(0, 100.00%, 79.45%); opacity: 0.88" title="-0.024">ا</span><span style="background-color: hsl(0, 100.00%, 84.32%); opacity: 0.85" title="-0.017">ل</span><span style="background-color: hsl(120, 100.00%, 98.78%); opacity: 0.80" title="0.000">ا</span><span style="background-color: hsl(120, 100.00%, 79.20%); opacity: 0.88" title="0.025">ح</span><span style="background-color: hsl(0, 100.00%, 87.29%); opacity: 0.84" title="-0.012">ت</span><span style="background-color: hsl(0, 100.00%, 76.65%); opacity: 0.89" title="-0.029">را</span><span style="opacity: 0.80">ز</span><span style="background-color: hsl(0, 100.00%, 83.19%); opacity: 0.86" title="-0.018">..</span><span style="background-color: hsl(0, 100.00%, 77.25%); opacity: 0.89" title="-0.028"> </span><span style="background-color: hsl(0, 100.00%, 89.06%); opacity: 0.83" title="-0.010">تب</span><span style="opacity: 0.80">ع</span><span style="background-color: hsl(120, 100.00%, 89.53%); opacity: 0.83" title="0.009">ثر </span><span style="opacity: 0.80">أفك</span><span style="background-color: hsl(120, 100.00%, 71.32%); opacity: 0.92" title="0.039">ا</span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.063">رك</span><span style="background-color: hsl(120, 100.00%, 70.22%); opacity: 0.93" title="0.042"> </span><span style="background-color: hsl(120, 100.00%, 83.68%); opacity: 0.86" title="0.018">و</span><span style="background-color: hsl(120, 100.00%, 60.38%); opacity: 1.00" title="0.062">م</span><span style="background-color: hsl(120, 100.00%, 68.57%); opacity: 0.94" title="0.045">ش</span><span style="background-color: hsl(120, 100.00%, 63.49%); opacity: 0.98" title="0.056">ا</span><span style="background-color: hsl(120, 100.00%, 88.47%); opacity: 0.83" title="0.011">ع</span><span style="background-color: hsl(120, 100.00%, 73.77%); opacity: 0.91" title="0.035">ر</span><span s ...
#     </p>
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # Feel free to play with notebook explore different models with different datasets
